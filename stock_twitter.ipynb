# %%
# %matplotlib inline

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
import seaborn as sns
import time
import tweepy
from datetime import datetime
 
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from tw_config import (consumer_key,
                       consumer_secret,
                       access_token,
                       access_token_secret)

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Load S&P500 Company List
df_sp500 = pd.read_csv('Resources/SP500_Company_List.csv')

df_sp500.head()
# Out:
#   Ticker             Security             GICS Sector  \
# 0    MMM           3M Company             Industrials
# 1    ABT  Abbott Laboratories             Health Care
# 2   ABBV          AbbVie Inc.             Health Care
# 3   ABMD          ABIOMED Inc             Health Care
# 4    ACN        Accenture plc  Information Technology
#
#                 GICS Sub Industry                 Location  Date Added  \
# 0        Industrial Conglomerates      St. Paul, Minnesota         NaN
# 1           Health Care Equipment  North Chicago, Illinois   3/31/1964
# 2                 Pharmaceuticals  North Chicago, Illinois  12/31/2012
# 3           Health Care Equipment   Danvers, Massachusetts   5/31/2018
# 4  IT Consulting & Other Services          Dublin, Ireland    7/6/2011
#
#        CIK
# 0    66740
# 1     1800
# 2  1551152
# 3   815094
# 4  1467373

# %%
# Find Twitter handles for S&P500 Companies - RUN IF "SP500_twtr_ids.csv" DOES NOT ALREADY EXIST. 
twtr_ids = []

# Search for Twitter handles by Company Name
for index, row in df_sp500.iterrows(): 
    try:
        user_id = ''
        screen_name = ''
        name = ''
        
        time.sleep(1)                                                  # Keep API Calls under limit
        public_users = api.search_users(row.Security)
        re_name = re.search('[\w]+', row.Security)
        loc = re.search('[\w]+$', row.Location)
        if len(public_users) > 0:
            for user in public_users:
                if (re_name.group(0).lower() in user['name'].lower()):
                    user_id = user['id']
                    screen_name = user['screen_name']
                    name = user['name']
                    break
                
                elif (row.Security.lower() in user['name'].lower()):
                    user_id = user['id']
                    screen_name = user['screen_name']
                    name = user['name']
                
        twtr_ids.append([row.Ticker, row.Security, loc.group(0).lower(), user_id, screen_name, name])
        #print(f'Company Match: [{row.Ticker},{row.Security},{loc.group(0).lower()},{user_id},{screen_name},{name}]')
        
    except Exception as e:
        print(e)

# Search for Twitter handles with different company name search
for i in range(len(twtr_ids)):
    try:
        if twtr_ids[i][3] == '':                                     # Check if user_id is blank
            time.sleep(1)                                                # Keep API Calls under limit
            re_name = re.search('[\w]+ [\w]+', twtr_ids[i][1])
            if re_name != None:
                public_users = api.search_users(re_name.group(0).lower())
            
                if len(public_users) > 0:
                    for user in public_users:
                        if (re_name.group(0).lower() in user['name'].lower()):
                            user_id = user['id']
                            screen_name = user['screen_name']
                            name = user['name']
                            twtr_ids[i] = [twtr_ids[i][0],twtr_ids[i][1],twtr_ids[i][2],user_id,screen_name,name]
                            #print(f'2nd Company Search: {twtr_ids[i]}')
                            break
                           
                        elif (twtr_ids[i][1].lower() in user['name'].lower()):
                            user_id = user['id']
                            screen_name = user['screen_name']
                            name = user['name']
                            twtr_ids[i] = [twtr_ids[i][0],twtr_ids[i][1],twtr_ids[i][2],user_id,screen_name,name]
                            #print(f'2nd Company Search: {twtr_ids[i]}')
                            
    except Exception as e:
        print(e)        
        
# Search for Twitter handles by ticker symbol
for i in range(len(twtr_ids)):
    try:
        if twtr_ids[i][3] == '':                                     # Check if user_id is blank
            time.sleep(1)                                                # Keep API Calls under limit
            public_users = api.search_users(f'${twtr_ids[i][0]}')
            
            if len(public_users) > 0:
                for user in public_users:
                    if re.search('[\w]+', twtr_ids[i][1]) != None:
                        if re.search('[\w]+', twtr_ids[i][1]).group(0).lower() in user['name'].lower():
                            user_id = user['id']
                            screen_name = user['screen_name']
                            name = user['name']
                            twtr_ids[i] = [twtr_ids[i][0],twtr_ids[i][1],twtr_ids[i][2],user_id,screen_name,name]
                            #print(f'Ticker Match: {twtr_ids[i]}')
                            break
                        
                    elif re.search('[\w]+ [\w]+', twtr_ids[i][1]) != None:
                        if re.search('[\w]+ [\w]+', twtr_ids[i][1]).group(0).lower() in user['name'].lower():
                            user_id = user['id']
                            screen_name = user['screen_name']
                            name = user['name']
                            twtr_ids[i] = [twtr_ids[i][0],twtr_ids[i][1],twtr_ids[i][2],user_id,screen_name,name]
                            #print(f'Ticker Match: {twtr_ids[i]}')
                            break
                        
                    elif (twtr_ids[i][0] == user['name']) and (user['followers_count'] > 10000):
                        user_id = user['id']
                        screen_name = user['screen_name']
                        name = user['name']
                        twtr_ids[i] = [twtr_ids[i][0],twtr_ids[i][1],twtr_ids[i][2],user_id,screen_name,name]
                        #print(f'Ticker Match: {twtr_ids[i]}')
                      
    except Exception as e:
        print(e)

df_twtr_ids = pd.DataFrame(twtr_ids, columns=['ticker','security','location','user_id','screen_name','twtr_name'])
df_twtr_ids = df_twtr_ids.drop(columns=['location'])
df_twtr_ids.to_csv('Resources/SP500_twtr_ids.csv', index=False)
# Out:
# 'NoneType' object has no attribute 'group'
# 'NoneType' object has no attribute 'group'
# 'NoneType' object has no attribute 'group'
# 'NoneType' object has no attribute 'group'
# 'NoneType' object has no attribute 'group'
# 'NoneType' object has no attribute 'group'
# 'NoneType' object has no attribute 'group'
# 'NoneType' object has no attribute 'group'
# 'NoneType' object has no attribute 'group'

# %%
df_sp500 = df_sp500[450:]

# %%
# Get Twitter Sentiments for S&P500 Companies
twtr_sentiments = []

for index, row in df_sp500.iterrows(): 
    try:
        # Create search name to use in Twitter search
        re_name = re.search('[\w]+ [\w]+', row.Security)
        
        # Verify that search name is not null 
        if re_name == None: 
            re_name = re.search('[\w]+', row.Security)
            
        # Create Twitter search term
        target_term = f'{re_name.group(0)} ${row.Ticker}'
        
        # Perform search of most recent 100 tweets
        time.sleep(5)
        public_tweets = api.search(target_term, count=100)
        
        for tweet in public_tweets['statuses']:
            twt_date = datetime.strptime(tweet["created_at"], "%a %b %d %H:%M:%S %z %Y")
            twt_fdate = twt_date.strftime('%Y%m%d')
            twt_yr = twt_date.strftime('%Y')
            twt_md = twt_date.strftime('%m%d')
            
            twt_text = tweet['text']
            vdr_results = analyzer.polarity_scores(twt_text)
            compound = vdr_results['compound']
            neg = vdr_results['neg']
            neu = vdr_results['neu']
            pos = vdr_results['pos']
            
            # Create row for Twitter sentiment list
            twtr_sentiments.append([row.Ticker, row.Security, twt_fdate, twt_yr, twt_md, compound, neg, neu, pos, twt_text])
    
    except Exception as e:
        print(e)

#Create dataframe for Twitter sentiments
data_columns = ('ticker','company','date','year','monthday','compound_score','neg_score','neu_score','pos_score','tweet')

df_twtr_sentiments = pd.DataFrame(twtr_sentiments, columns=data_columns)

qtr_bins = [0,331,630,930,1231]
qtr_labels = ['Q1', 'Q2', 'Q3', 'Q4']

twt_qtr = pd.cut(pd.to_numeric(df_twtr_sentiments.monthday, errors='coerce'), qtr_bins, labels=qtr_labels)

quarter = []

for x in range(len(twt_qtr)):
    quarter.append(str(df_twtr_sentiments.year[x]) + str(twt_qtr[x]))

df_twtr_sentiments['quarter'] = quarter

df_twtr_sentiments = df_twtr_sentiments.drop(columns=['monthday'])

df_twtr_sentiments.to_csv('Resources/SP500_sentiments10.csv', index=False)

# %%
df_data = pd.read_csv('Resources/SP500_sentiments1.csv')
for i in range(2,11):
    df_data = df_data.merge(pd.read_csv(f'Resources/SP500_sentiments{i}.csv'),how='outer')
    
df_data.to_csv('Resources/SP500_sentiments.csv')

# %%
public_tweets = api.search('$MMM debt')
public_tweets
# Out:
# {'search_metadata': {'completed_in': 0.023,
#   'count': 15,
#   'max_id': 1013522033202696192,
#   'max_id_str': '1013522033202696192',
#   'query': '%24MMM+debt',
#   'refresh_url': '?since_id=1013522033202696192&q=%24MMM%20debt&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Jul 01 20:37:37 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1013522033202696192',
#       'indices': [123, 146],
#       'url': 'https://t.co/C79JF5eeiZ'}],
#     'user_mentions': [{'id': 16397147,
#       'id_str': '16397147',
#       'indices': [0, 14],
#       'name': 'Liberal Party',
#       'screen_name': 'liberal_party'},
#      {'id': 3341414159,
#       'id_str': '3341414159',
#       'indices': [15, 27],
#       'name': 'Ginette Petitpas Taylor',
#       'screen_name': 'GPTaylorMRD'},
#      {'id': 14260960,
#       'id_str': '14260960',
#       'indices': [28, 42],
#       'name': 'Justin Trudeau',
#       'screen_name': 'JustinTrudeau'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1013522033202696192,
#    'id_str': '1013522033202696192',
#    'in_reply_to_screen_name': 'AliceOutThere',
#    'in_reply_to_status_id': 1013519977356275713,
#    'in_reply_to_status_id_str': '1013519977356275713',
#    'in_reply_to_user_id': 2305623013,
#    'in_reply_to_user_id_str': '2305623013',
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': '@liberal_party @GPTaylorMRD @JustinTrudeau It is now 2018\n21st century&lt;--&gt;1st World Country\nO Canada 🇨🇦\nCanada is a… https://t.co/C79JF5eeiZ',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Jan 22 23:30:12 +0000 2014',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'We gotta get this right for M.E.--NOW!   2 many lives lost--wasted--stolen. Outrageous neglect & medical MIStreatment--by our govts. SHAME on them!! Fight back!',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 60078,
#     'follow_request_sent': False,
#     'followers_count': 1638,
#     'following': False,
#     'friends_count': 1316,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 2305623013,
#     'id_str': '2305623013',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 138,
#     'location': '',
#     'name': 'Alice Lewis',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/778708294290382848/_FhJXZnz_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/778708294290382848/_FhJXZnz_normal.jpg',
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'AliceOutThere',
#     'statuses_count': 73419,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Jun 26 18:37:32 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [{'indices': [18, 23], 'text': 'PTEN'},
#      {'indices': [24, 28], 'text': 'NWL'},
#      {'indices': [29, 33], 'text': 'TJX'},
#      {'indices': [34, 38], 'text': 'EPD'},
#      {'indices': [39, 43], 'text': 'TBT'},
#      {'indices': [44, 47], 'text': 'NE'},
#      {'indices': [48, 52], 'text': 'TAL'},
#      {'indices': [53, 58], 'text': 'SPXS'},
#      {'indices': [59, 64], 'text': 'MXIM'},
#      {'indices': [65, 70], 'text': 'WELL'},
#      {'indices': [71, 75], 'text': 'MMM'},
#      {'indices': [76, 80], 'text': 'SRC'},
#      {'indices': [81, 85], 'text': 'CSX'},
#      {'indices': [86, 90], 'text': 'KBR'},
#      {'indices': [91, 95], 'text': 'MHK'},
#      {'indices': [96, 100], 'text': 'ODP'},
#      {'indices': [101, 105], 'text': 'MHK'},
#      {'indices': [106, 110], 'text': 'SRC'},
#      {'indices': [111, 115], 'text': 'PEP'}],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1011679872039583744',
#       'indices': [117, 140],
#       'url': 'https://t.co/LbRSNlHL1n'}],
#     'user_mentions': []},
#    'favorite_count': 2,
#    'favorited': False,
#    'geo': None,
#    'id': 1011679872039583744,
#    'id_str': '1011679872039583744',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': True,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'quoted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Jun 26 18:30:41 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [{'indices': [0, 5], 'text': 'LIBE'}],
#      'urls': [{'display_url': 'archive.fast-edgar.com//20180626/AS2Z…',
#        'expanded_url': 'http://archive.fast-edgar.com//20180626/AS2ZT22CZ22RM2MZ2U2T2MX2OOHNZZ22ZVA2/',
#        'indices': [15, 38],
#        'url': 'https://t.co/7EWkhZfALN'}],
#      'user_mentions': []},
#     'favorite_count': 5,
#     'favorited': False,
#     'geo': None,
#     'id': 1011678147480375298,
#     'id_str': '1011678147480375298',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 2,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'text': '$LIBE FORM 8-K\nhttps://t.co/7EWkhZfALN',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Mon Oct 30 17:40:30 +0000 2017',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'Day Trader, Sharing both positive /negative stock News/ Filings/ Breaking Material Events. MY tweets are 100% Compensation FREE!⚠️Traders should do their own DD',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 85,
#      'follow_request_sent': False,
#      'followers_count': 489,
#      'following': False,
#      'friends_count': 51,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 925054821048168449,
#      'id_str': '925054821048168449',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 3,
#      'location': '',
#      'name': 'TheBull©',
#      'notifications': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/925054821048168449/1509396327',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/928057059702132736/G6iw36Vi_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/928057059702132736/G6iw36Vi_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'TheBull_Stocks',
#      'statuses_count': 2455,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': None,
#      'verified': False}},
#    'quoted_status_id': 1011678147480375298,
#    'quoted_status_id_str': '1011678147480375298',
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': '8K out. Debt paid $PTEN $NWL $TJX $EPD $TBT $NE $TAL $SPXS $MXIM $WELL $MMM $SRC $CSX $KBR $MHK $ODP $MHK $SRC $PEP… https://t.co/LbRSNlHL1n',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri May 26 16:09:50 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Always do your own DD and make your own decisions. Or.... follow me. lol........ No, really, do your own DD',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 5232,
#     'follow_request_sent': False,
#     'followers_count': 912,
#     'following': False,
#     'friends_count': 489,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 868137108766052352,
#     'id_str': '868137108766052352',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 2,
#     'location': 'ALASKA',
#     'name': "OneO'ClockDrop",
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/868137108766052352/1495821868',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/869301494821957632/ZzKkmpZS_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/869301494821957632/ZzKkmpZS_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'OneOClockDrop',
#     'statuses_count': 4005,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Jun 26 18:00:48 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [{'indices': [39, 44], 'text': 'PTEN'},
#      {'indices': [45, 49], 'text': 'NWL'},
#      {'indices': [50, 54], 'text': 'TJX'},
#      {'indices': [55, 59], 'text': 'EPD'},
#      {'indices': [60, 64], 'text': 'TBT'},
#      {'indices': [65, 68], 'text': 'NE'},
#      {'indices': [69, 73], 'text': 'TAL'},
#      {'indices': [74, 79], 'text': 'SPXS'},
#      {'indices': [80, 85], 'text': 'MXIM'},
#      {'indices': [86, 91], 'text': 'WELL'},
#      {'indices': [92, 96], 'text': 'MMM'},
#      {'indices': [97, 101], 'text': 'SRC'},
#      {'indices': [102, 106], 'text': 'CSX'},
#      {'indices': [107, 111], 'text': 'KBR'}],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1011670628603125760',
#       'indices': [113, 136],
#       'url': 'https://t.co/P1dTJW6XtV'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1011670628603125760,
#    'id_str': '1011670628603125760',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': True,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'quoted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Jun 26 10:32:25 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1011557788567339008',
#        'indices': [116, 139],
#        'url': 'https://t.co/U2y0rl8JYj'}],
#      'user_mentions': []},
#     'favorite_count': 52,
#     'favorited': False,
#     'geo': None,
#     'id': 1011557788567339008,
#     'id_str': '1011557788567339008',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 17,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'text': 'I just requested our attorney to file the 8-K when he gets in today. Total debt resolved $413,413. No active notes… https://t.co/U2y0rl8JYj',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sat Jul 04 00:47:52 +0000 2015',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': '',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 11,
#      'follow_request_sent': False,
#      'followers_count': 2644,
#      'following': False,
#      'friends_count': 53,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 3267558878,
#      'id_str': '3267558878',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 7,
#      'location': '',
#      'name': 'Liberated Energy',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3267558878/1437103865',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/619885358491172864/vKZAGCxY_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/619885358491172864/vKZAGCxY_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'LIBEnergy',
#      'statuses_count': 171,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': None,
#      'verified': False}},
#    'quoted_status_id': 1011557788567339008,
#    'quoted_status_id_str': '1011557788567339008',
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'DEBT PAID. LOOK AT THE TWITTER ACCOUNT $PTEN $NWL $TJX $EPD $TBT $NE $TAL $SPXS $MXIM $WELL $MMM $SRC $CSX $KBR… https://t.co/P1dTJW6XtV',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri May 26 16:09:50 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Always do your own DD and make your own decisions. Or.... follow me. lol........ No, really, do your own DD',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 5232,
#     'follow_request_sent': False,
#     'followers_count': 912,
#     'following': False,
#     'friends_count': 489,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 868137108766052352,
#     'id_str': '868137108766052352',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 2,
#     'location': 'ALASKA',
#     'name': "OneO'ClockDrop",
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/868137108766052352/1495821868',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/869301494821957632/ZzKkmpZS_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/869301494821957632/ZzKkmpZS_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'OneOClockDrop',
#     'statuses_count': 4005,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}}]}
